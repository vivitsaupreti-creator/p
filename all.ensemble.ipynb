# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("Telco-Customer-Churn.csv")

# %%
df.TotalCharges= pd.to_numeric(df.TotalCharges, errors='coerce')
df.dropna(how="any", inplace=True)

# %%
X = df.drop(["customerID", "Churn"], axis=1)
Y = df["Churn"].values

# %%
X= pd.get_dummies(X,columns=['gender', 'Partner', 'Dependents', 'PhoneService',
        'MultipleLines', 'InternetService', 'OnlineSecurity',
        'OnlineBackup', 'DeviceProtection', 'TechSupport',
        'StreamingTV', 'StreamingMovies', 'Contract',
        'PaperlessBilling', 'PaymentMethod'], drop_first=True)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test= train_test_split(X,Y,test_size=0.25)

# %%
from sklearn.preprocessing import StandardScaler
model= StandardScaler()
X_train= model.fit_transform(X_train)
X_test= model.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
model_knn= KNeighborsClassifier()
model_knn.fit(X_train,Y_train)
Y_pred_knn= model_knn.predict(X_test)

# %%
from sklearn.naive_bayes import BernoulliNB
model_nb= BernoulliNB()
model_nb.fit(X_train,Y_train)
Y_pred_nb= model_nb.predict(X_test)

# %%
from sklearn.svm import SVC
model_svm= SVC()
model_svm.fit(X_train,Y_train)
Y_pred_svm= model_svm.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print("knn_accuracy", accuracy_score(Y_test,Y_pred_knn)*100)
print("svm_accuracy", accuracy_score(Y_test,Y_pred_svm)*100)
print("nb_accuracy", accuracy_score(Y_test,Y_pred_nb)*100)
# Out:
# knn_accuracy 76.45051194539249
# svm_accuracy 79.92036405005688
# nb_accuracy 73.20819112627987

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf= RandomForestClassifier()
model_rf.fit(X_train,Y_train)
Y_pred_rf= model_rf.predict(X_test)
print(accuracy_score(Y_test,Y_pred_rf)*100)
# Out:
# 78.72582480091013

# %%
from sklearn.metrics import classification_report
print("knn_classification_report", classification_report(Y_test,Y_pred_knn))
print("random_forest_classification report", classification_report(Y_test,Y_pred_rf))
# Out:
# knn_classification_report               precision    recall  f1-score   support
#
#           No       0.83      0.86      0.84      1306
#          Yes       0.55      0.50      0.52       452
#
#     accuracy                           0.76      1758
#    macro avg       0.69      0.68      0.68      1758
# weighted avg       0.76      0.76      0.76      1758
#
# random_forest_classification report               precision    recall  f1-score   support
#
#           No       0.83      0.90      0.86      1306
#          Yes       0.61      0.47      0.53       452
#
#     accuracy                           0.79      1758
#    macro avg       0.72      0.68      0.70      1758
# weighted avg       0.77      0.79      0.78      1758

# %%
print("svm_classification_report", classification_report(Y_test,Y_pred_svm))
print("nb_classification_report", classification_report(Y_test,Y_pred_nb))
# Out:
# svm_classification_report               precision    recall  f1-score   support
#
#           No       0.84      0.91      0.87      1306
#          Yes       0.65      0.48      0.55       452
#
#     accuracy                           0.80      1758
#    macro avg       0.74      0.70      0.71      1758
# weighted avg       0.79      0.80      0.79      1758
#
# nb_classification_report               precision    recall  f1-score   support
#
#           No       0.92      0.70      0.80      1306
#          Yes       0.49      0.81      0.61       452
#
#     accuracy                           0.73      1758
#    macro avg       0.70      0.76      0.70      1758
# weighted avg       0.81      0.73      0.75      1758

# %%
from sklearn.ensemble import AdaBoostClassifier
model_ada= AdaBoostClassifier(n_estimators=200)
model_ada.fit(X_train,Y_train)
Y_pred_ada= model_ada.predict(X_test)
print("ada booste accuracy_score", accuracy_score(Y_test,Y_pred_ada)*100)
# Out:
# ada booste accuracy_score 79.806598407281

# %%
from sklearn.ensemble import GradientBoostingClassifier
model_gb= GradientBoostingClassifier(n_estimators=200)
model_gb.fit( X_train,Y_train)
Y_pred_gb= model_gb.predict(X_test)
print("gradient booste accuracy_score", accuracy_score(Y_test,Y_pred_gb)*100)
# Out:
# gradient booste accuracy_score 79.74971558589306

# %%
from xgboost import XGBClassifier
model_xgb= XGBoostClassifier(n_estimators=200)
model_xgb.fit(X_train,Y_train)
Y_pred_xgb= model_xgb.predict(X_test)
print("XGB accuracy_score", accuracy_score(Y_test,Y_pred_xgb)*100)
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from xgboost import XGBClassifier
#       2 model_xgb= XGBoostClassifier(n_estimators=200)
#       3 model_xgb.fit(X_train,Y_train)
#       4 Y_pred_xgb= model_xgb.predict(X_test)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/xgboost/__init__.py:6
#       1 """XGBoost: eXtreme Gradient Boosting library.
#       2
#       3 Contributors: https://github.com/dmlc/xgboost/blob/master/CONTRIBUTORS.md
#       4 """
# ----> 6 from . import (
#       7     collective,
#       8     interpret,
#       9     tracker,  # noqa
#      10 )
#      11 from ._c_api import _py_version
#      12 from .core import (
#      13     Booster,
#      14     DataIter,
#    (...)     18     build_info,
#      19 )
#
# ...
