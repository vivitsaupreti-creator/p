# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score 
from sklearn.ensemble import BaggingClassifier 
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
X, Y = make_classification(n_samples=10000, n_features=10, n_informative=3)

# %%
X_train,X_test,Y_train,Y_test= train_test_split(
    X,Y,test_size=0.2, random_state=42
)

# %%
model_dt= DecisionTreeClassifier()
model_dt.fit(X_train,Y_train)
Y_pred_dt= model_dt.predict(X_test)
print(accuracy_score(Y_pred_dt,Y_test)*100,2)
# Out:
# 92.35 2

# %% [markdown]
#                                        bagging classifier

# %%
bag= BaggingClassifier(estimator= DecisionTreeClassifier(),n_estimators=500,max_samples=0.5,bootstrap=True,random_state=42,)

# %%
bag.fit(X_train,Y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), max_samples=0.5,
#                   n_estimators=500, random_state=42)

# %%
Y_pred_bag= bag.predict(X_test)
print(accuracy_score(Y_test,Y_pred_bag)*100)
# Out:
# 94.75

# %%
from sklearn.ensemble import RandomForestClassifier
model= RandomForestClassifier(random_state=45, n_estimators=500)
model.fit(X_train,Y_train)
Y_pred_rf= model.predict(X_test)
print(accuracy_score(Y_test,Y_pred_rf)*100)
# Out:
# 94.89999999999999

# %%
bag= BaggingClassifier(estimator = SVC(),n_estimators=500,max_samples=0.25,bootstrap=True,random_state=42)

# %%
bag.fit(X_train,Y_train)
# Out:
# BaggingClassifier(estimator=SVC(), max_samples=0.25, n_estimators=500,
#                   random_state=42)

# %%
Y_pred_svm=bag.predict(X_test)
print(accuracy_score(Y_test,Y_pred_svm)*100)
# Out:
# 93.05

# %% [markdown]
#                         BAGGING REGRESSORS

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
bagg= BaggingRegressor(estimator=DecisionTreeClassifier(),n_estimators=500,max_samples=0.5,bootstrap=True,random_state=42)

# %%
bagg.fit(X_train,Y_train)
# Out:
# BaggingRegressor(estimator=DecisionTreeClassifier(), max_samples=0.5,
#                  n_estimators=500, random_state=42)

# %%
Y_pred_bagg= bagg.predict(X_test)

# %%
from sklearn.tree import DecisionTreeRegressor
model_dtr= DecisionTreeRegressor(random_state=45)
model_dtr.fit(X_train,Y_train)
Y_pred_dtr= model_dtr.predict(X_test)

# %%
print("Decision Tree R^2 Score:", r2_score(Y_test, Y_pred_dtr))
print("Decision Tree MSE:", mean_squared_error(Y_test, Y_pred_dtr))
print("Decision Tree MAE:", mean_absolute_error(Y_test, Y_pred_dtr))
# Out:
# Decision Tree R^2 Score: 0.6798719487795117
# Decision Tree MSE: 0.08
# Decision Tree MAE: 0.08

# %%
print("bagged tree R2 score", r2_score(Y_test,Y_pred_bagg))
print("bagged tree Mean Square Error",mean_squared_error(Y_test,Y_pred_bagg))
print("bagged tree mean absolute error",mean_absolute_error(Y_test,Y_pred_bagg))
# Out:
# bagged tree R2 score 0.8428167266906762
# bagged tree Mean Square Error 0.039280100000000005
# bagged tree mean absolute error 0.08492400000000001

# %%
from sklearn.ensemble import RandomForestRegressor
model_rfr= RandomForestRegressor(random_state=45, n_estimators=500)
model_rfr.fit(X_train,Y_train)
Y_pred_rfr= model_rfr.predict(X_test)

# %%
print('RandomForest r2_score:', r2_score(Y_test,Y_pred_rfr))
print("RandomForest Mean Square Error:", mean_squared_error(Y_test,Y_pred_rfr)) 
print("RandomForest Mean Absolute Error",mean_absolute_error(Y_test,Y_pred_rfr))
# Out:
# RandomForest r2_score: 0.8441301160464185
# RandomForest Mean Square Error: 0.038951884
# RandomForest Mean Absolute Error 0.08216400000000001
